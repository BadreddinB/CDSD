# %% [markdown]
# # KAYAK - DATA INFRASTRUCTURE PIPELINE
#
# ## Business Context
#
# Kayak is a travel search engine aiming to help users plan their next holidays based on reliable and objective data.
#
# User research conducted by the Marketing team highlighted that:
# - 70% of users would like more trusted information about destinations before booking
# - Users tend to distrust content if the data source is unknown
#
# Therefore, the Marketing team wants to build a recommendation application able to suggest:
#
# - The best destinations to travel to
# - The best hotels available in those destinations
#
# based on real-time environmental conditions such as:
#
# - Weather forecast
# - Accommodation quality
#
# To support this application, a data infrastructure must be implemented in order to collect, store, process and expose reliable travel-related data.
#
# This notebook presents the implementation of a Data Engineering pipeline designed to support this business need.

# %% [markdown]
# ## Imports

# %%
import requests
import pandas as pd
import time

# %% [markdown]
# ## Data Architecture Overview
#
# In order to support Kayak’s future recommendation system, a data infrastructure has been designed following a modern Data Lake / Data Warehouse architecture:
#
# ### Data Sources
# - Geolocation API (Nominatim)
# - Weather API (Open-Meteo)
# - Hotel information (Booking.com scraping)
#
# ### Data Lake (AWS S3)
# Raw and enriched data collected from external sources are stored in a centralized storage layer (AWS S3) acting as a Data Lake.
#
# ### ETL Pipeline
# An Extract – Transform – Load process is implemented to:
# - Clean collected hotel data
# - Standardize review scores
# - Handle missing values
# - Compute a climate attractiveness indicator
#
# ### Data Warehouse (AWS RDS PostgreSQL)
# Cleaned and enriched data are then loaded into a structured relational database in order to:
# - Facilitate downstream analysis
# - Enable marketing teams to query trusted travel insights

# %% [markdown]
# ## Destinations Scope Definition

# %%
CITIES = [
    "Mont Saint Michel", "St Malo", "Bayeux", "Le Havre", "Rouen",
    "Paris", "Amiens", "Lille", "Strasbourg",
    "Chateau du Haut Koenigsbourg", "Colmar", "Eguisheim",
    "Besancon", "Dijon", "Annecy", "Grenoble", "Lyon",
    "Gorges du Verdon", "Bormes les Mimosas", "Cassis", "Marseille",
    "Aix en Provence", "Avignon", "Uzes", "Nimes", "Aigues Mortes",
    "Saintes Maries de la mer", "Collioure", "Carcassonne",
    "Ariege", "Toulouse", "Montauban", "Biarritz", "Bayonne",
    "La Rochelle"
]

NOMINATIM_API_URL = "https://nominatim.openstreetmap.org/search"
HEADERS = {"User-Agent": "kayak-data-team"}

# %% [markdown]
# ## GPS Coordinates Collection

# %%
gps_data=[]

for idx, city in enumerate(CITIES, start=1):

    params = {
        "q": f"{city}, France",
        "format": "json",
        "limit":1
    }

    response = requests.get(
        NOMINATIM_API_URL,
        headers=HEADERS,
        params=params
    )

    time.sleep(1)

    if response.status_code==200 and response.json():
        lat = response.json()[0]["lat"]
        lon = response.json()[0]["lon"]
    else:
        lat, lon = None, None

    gps_data.append({
        "city_id": idx,
        "city_name": city,
        "latitude": lat,
        "longitude": lon,
    })        
cities_df= pd.DataFrame(gps_data)
cities_df
# Out:
#     city_id                     city_name    latitude   longitude
# 0         1             Mont Saint Michel  48.6359541  -1.5114600
# 1         2                       St Malo  48.6495180  -2.0260409
# 2         3                        Bayeux  49.2764624  -0.7024738
# 3         4                      Le Havre  49.4938975   0.1079732
# 4         5                         Rouen  49.4404591   1.0939658
# 5         6                         Paris  48.8534951   2.3483915
# 6         7                        Amiens  49.8941708   2.2956951
# 7         8                         Lille  50.6365654   3.0635282
# 8         9                    Strasbourg  48.5846140   7.7507127
# 9        10  Chateau du Haut Koenigsbourg  48.2493820   7.3439412
# 10       11                        Colmar  48.0777517   7.3579641
# 11       12                     Eguisheim  48.0447968   7.3079618
# 12       13                      Besancon  47.2380222   6.0243622
# 13       14                         Dijon  47.3215806   5.0414701
# 14       15                        Annecy  45.8992348   6.1288847
# 15       16                      Grenoble  45.1875602   5.7357819
# 16       17                          Lyon  45.7578137   4.8320114
# 17       18              Gorges du Verdon  43.7496562   6.3285616
# 18       19            Bormes les Mimosas  43.1506968   6.3419285
# 19       20                        Cassis  43.2140359   5.5396318
# 20       21                     Marseille  43.2961743   5.3699525
# 21       22               Aix en Provence  43.5298424   5.4474738
# 22       23                       Avignon  43.9492493   4.8059012
# 23       24                          Uzes  44.0121279   4.4196718
# 24       25                         Nimes  43.8374249   4.3600687
# 25       26                 Aigues Mortes  43.5661521   4.1915400
# 26       27      Saintes Maries de la mer  43.4515922   4.4277202
# 27       28                     Collioure  42.5250500   3.0831554
# 28       29                   Carcassonne  43.2130358   2.3491069
# 29       30                        Ariege  42.9455368   1.4065544
# 30       31                      Toulouse  43.6044638   1.4442433
# 31       32                     Montauban  44.0175835   1.3549991
# 32       33                      Biarritz  43.4832523  -1.5592776
# 33       34                       Bayonne  43.4945144  -1.4736657
# 34       35                   La Rochelle  46.1597320  -1.1515951

# %% [markdown]
# ## Weather Data Collection

# %%
OPENMETEO_API_URL = "https://api.open-meteo.com/v1/forecast"

# %%
weather_data = []

for _, row in cities_df.iterrows():

    params = {
        "latitude": row["latitude"],
        "longitude": row["longitude"],
        "daily": "temperature_2m_max,precipitation_sum",
        "forecast_days": 7,
        "timezone": "auto"
    }

    response = requests.get(OPENMETEO_API_URL, params=params)

    if response.status_code == 200:

        data = response.json()

        rain = sum(data["daily"]["precipitation_sum"])
        temp = sum(data["daily"]["temperature_2m_max"]) / 7

        weather_data.append({
            "city_id": row["city_id"],
            "city_name": row["city_name"],
            "rain_7d": rain,
            "avg_temp_7d": temp
        })

    else:
        print(f"Error for {row['city_name']} : {response.status_code}")    

print(len(weather_data))

weather_df = pd.DataFrame(weather_data)
weather_df
# Out:
# 35
#     city_id                     city_name  rain_7d  avg_temp_7d
# 0         1             Mont Saint Michel     8.48    13.300000
# 1         2                       St Malo     7.58    13.542857
# 2         3                        Bayeux    13.50    13.542857
# 3         4                      Le Havre    16.70    12.500000
# 4         5                         Rouen    18.60    13.785714
# 5         6                         Paris    12.35    14.942857
# 6         7                        Amiens     9.90    14.128571
# 7         8                         Lille    13.60    13.314286
# 8         9                    Strasbourg     9.30    14.242857
# 9        10  Chateau du Haut Koenigsbourg     5.96    11.357143
# 10       11                        Colmar     1.63    15.171429
# 11       12                     Eguisheim     2.92    14.257143
# 12       13                      Besancon     3.50    14.900000
# 13       14                         Dijon     0.30    14.500000
# 14       15                        Annecy     1.80    15.000000
# 15       16                      Grenoble     0.00    17.671429
# 16       17                          Lyon     2.70    15.314286
# 17       18              Gorges du Verdon     0.00    14.442857
# 18       19            Bormes les Mimosas     0.00    16.042857
# 19       20                        Cassis     0.00    16.585714
# 20       21                     Marseille     0.00    16.842857
# 21       22               Aix en Provence     0.00    16.614286
# 22       23                       Avignon     0.00    17.528571
# 23       24                          Uzes     0.00    16.871429
# 24       25                         Nimes     0.00    17.385714
# 25       26                 Aigues Mortes     0.00    16.442857
# 26       27      Saintes Maries de la mer     0.10    15.142857
# 27       28                     Collioure     0.00    16.657143
# 28       29                   Carcassonne     0.00    15.185714
# 29       30                        Ariege     0.90    13.342857
# 30       31                      Toulouse     2.40    16.528571
# 31       32                     Montauban     2.40    16.442857
# 32       33                      Biarritz     0.60    16.657143
# 33       34                       Bayonne     0.60    17.085714
# 34       35                   La Rochelle    13.80    13.642857

# %% [markdown]
# ## Weather Attractiveness Index Engineering
#
# In order to recommend destinations based on short-term travel comfort,
# a composite indicator named **Weather Score** has been engineered.
#
# This score aims to quantify the climatic attractiveness of each destination
# over the next 7 days by combining:
#
# - Average daily maximum temperature
# - Expected cumulative precipitation
#
# The objective of this index is to prioritize destinations offering:
# - Warmer temperatures
# - Lower rainfall levels
#
# This indicator will later be used by the Marketing team to identify
# the most suitable destinations for holiday planning.

# %% [markdown]
# ## Weather Score Calculation

# %%
weather_df["weather_score"] = (
    weather_df["avg_temp_7d"] - (weather_df["rain_7d"] * 0.5)
)

top_destinations = weather_df.sort_values(
    by="weather_score",
    ascending=False
).head(5)

top_destinations
# Out:
#     city_id  city_name  rain_7d  avg_temp_7d  weather_score
# 15       16   Grenoble      0.0    17.671429      17.671429
# 22       23    Avignon      0.0    17.528571      17.528571
# 24       25      Nimes      0.0    17.385714      17.385714
# 23       24       Uzes      0.0    16.871429      16.871429
# 20       21  Marseille      0.0    16.842857      16.842857

# %% [markdown]
# ## First Consolidation

# %%
cities_weather_df = cities_df.merge(
    weather_df,
    on=["city_id", "city_name"],
    how="inner"
)

cities_weather_df
# Out:
#     city_id                     city_name    latitude   longitude  rain_7d  \
# 0         1             Mont Saint Michel  48.6359541  -1.5114600     8.48
# 1         2                       St Malo  48.6495180  -2.0260409     7.58
# 2         3                        Bayeux  49.2764624  -0.7024738    13.50
# 3         4                      Le Havre  49.4938975   0.1079732    16.70
# 4         5                         Rouen  49.4404591   1.0939658    18.60
# 5         6                         Paris  48.8534951   2.3483915    12.35
# 6         7                        Amiens  49.8941708   2.2956951     9.90
# 7         8                         Lille  50.6365654   3.0635282    13.60
# 8         9                    Strasbourg  48.5846140   7.7507127     9.30
# 9        10  Chateau du Haut Koenigsbourg  48.2493820   7.3439412     5.96
# 10       11                        Colmar  48.0777517   7.3579641     1.63
# 11       12                     Eguisheim  48.0447968   7.3079618     2.92
# 12       13                      Besancon  47.2380222   6.0243622     3.50
# 13       14                         Dijon  47.3215806   5.0414701     0.30
# 14       15                        Annecy  45.8992348   6.1288847     1.80
# 15       16                      Grenoble  45.1875602   5.7357819     0.00
# 16       17                          Lyon  45.7578137   4.8320114     2.70
# 17       18              Gorges du Verdon  43.7496562   6.3285616     0.00
# 18       19            Bormes les Mimosas  43.1506968   6.3419285     0.00
# 19       20                        Cassis  43.2140359   5.5396318     0.00
# 20       21                     Marseille  43.2961743   5.3699525     0.00
# 21       22               Aix en Provence  43.5298424   5.4474738     0.00
# 22       23                       Avignon  43.9492493   4.8059012     0.00
# 23       24                          Uzes  44.0121279   4.4196718     0.00
# 24       25                         Nimes  43.8374249   4.3600687     0.00
# 25       26                 Aigues Mortes  43.5661521   4.1915400     0.00
# 26       27      Saintes Maries de la mer  43.4515922   4.4277202     0.10
# 27       28                     Collioure  42.5250500   3.0831554     0.00
# 28       29                   Carcassonne  43.2130358   2.3491069     0.00
# 29       30                        Ariege  42.9455368   1.4065544     0.90
# 30       31                      Toulouse  43.6044638   1.4442433     2.40
# 31       32                     Montauban  44.0175835   1.3549991     2.40
# 32       33                      Biarritz  43.4832523  -1.5592776     0.60
# 33       34                       Bayonne  43.4945144  -1.4736657     0.60
# 34       35                   La Rochelle  46.1597320  -1.1515951    13.80
#
#     avg_temp_7d  weather_score
# 0     13.300000       9.060000
# 1     13.542857       9.752857
# 2     13.542857       6.792857
# 3     12.500000       4.150000
# 4     13.785714       4.485714
# 5     14.942857       8.767857
# 6     14.128571       9.178571
# 7     13.314286       6.514286
# 8     14.242857       9.592857
# 9     11.357143       8.377143
# 10    15.171429      14.356429
# 11    14.257143      12.797143
# 12    14.900000      13.150000
# 13    14.500000      14.350000
# 14    15.000000      14.100000
# 15    17.671429      17.671429
# 16    15.314286      13.964286
# 17    14.442857      14.442857
# 18    16.042857      16.042857
# 19    16.585714      16.585714
# 20    16.842857      16.842857
# 21    16.614286      16.614286
# 22    17.528571      17.528571
# 23    16.871429      16.871429
# 24    17.385714      17.385714
# 25    16.442857      16.442857
# 26    15.142857      15.092857
# 27    16.657143      16.657143
# 28    15.185714      15.185714
# 29    13.342857      12.892857
# 30    16.528571      15.328571
# 31    16.442857      15.242857
# 32    16.657143      16.357143
# 33    17.085714      16.785714
# 34    13.642857       6.742857

# %%
import plotly.express as px

# %%
top_destinations_map = top_destinations.merge(
    cities_weather_df[["city_id", "latitude", "longitude"]],
    on="city_id",
    how="inner"
)

top_destinations_map["latitude"] = pd.to_numeric(top_destinations_map["latitude"], errors="coerce")
top_destinations_map["longitude"] = pd.to_numeric(top_destinations_map["longitude"], errors="coerce")

top_destinations_map
# Out:
#    city_id  city_name  rain_7d  avg_temp_7d  weather_score   latitude  \
# 0       16   Grenoble      0.0    17.671429      17.671429  45.187560
# 1       23    Avignon      0.0    17.528571      17.528571  43.949249
# 2       25      Nimes      0.0    17.385714      17.385714  43.837425
# 3       24       Uzes      0.0    16.871429      16.871429  44.012128
# 4       21  Marseille      0.0    16.842857      16.842857  43.296174
#
#    longitude
# 0   5.735782
# 1   4.805901
# 2   4.360069
# 3   4.419672
# 4   5.369953

# %%
fig = px.scatter_map(
    top_destinations_map,
    lat="latitude",
    lon="longitude",
    size="weather_score",
    color="weather_score",
    hover_name="city_name",
    hover_data=["rain_7d", "avg_temp_7d"],
    zoom=5,
    height=600
)

fig.show()

# %% [markdown]
# ## Hotel Information Collection (Web Scraping)
#
# As Booking Holdings does not provide aggregated public APIs for hotel data,
# hotel information has been collected directly from Booking.com through automated web scraping.
#
# The following attributes are retrieved for each hotel:
# - Hotel name
# - User review score
# - Booking page URL
# - Accommodation description
#
# This data will allow Kayak’s future recommendation system to:
# - Identify high-quality accommodation options
# - Associate hotel quality with destination attractiveness

# %% [markdown]
# ## Hotels Data Collection

# %%
from selenium.webdriver.firefox.service import Service as FirefoxService
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options as FirefoxOptions
from selenium.webdriver.common.by import By
from selenium import webdriver
import time
import random

# %%
options = FirefoxOptions()

options.add_argument("--width=1920")
options.add_argument("--height=1080")

driver = webdriver.Firefox(
    service=FirefoxService(GeckoDriverManager().install()),
    options=options
)

# %%
driver.get("https://www.booking.com")

time.sleep(5)

# %%
hotels_data = []

for _, row in top_destinations.iterrows():

    city = row["city_name"]

    url = f"https://www.booking.com/searchresults.html?ss={city}"

    driver.get(url)

    time.sleep(random.uniform(5,7))

    hotels = driver.find_elements(By.CSS_SELECTOR,'div[data-testid="property-card"]')[:20]

    print(f"{city} -> {len(hotels)} hotels found")

    for hotel in hotels:

        try:
            name = hotel.find_element(By.CSS_SELECTOR,'div[data-testid="title"]').text
        except:
            name = None

        try:
            score = hotel.find_element(By.CSS_SELECTOR,'div[data-testid="review-score"]').text
        except:
            score = None

        try:
            description = hotel.find_element(By.CSS_SELECTOR,'div[data-testid="property-card-unit-configuration"]').text
        except:
            description = None

        try:
            link = hotel.find_element(By.TAG_NAME,"a").get_attribute("href")
        except:
            link = None

        hotels_data.append({
            "city_id": row["city_id"],
            "city_name": city,
            "hotel_name": name,
            "review_score": score,
            "description": description,
            "booking_url": link
        })

    time.sleep(random.uniform(3,5))

hotels_df = pd.DataFrame(hotels_data)

driver.quit()
# Out:
# Grenoble -> 20 hotels found
# Avignon -> 20 hotels found
# Nimes -> 20 hotels found
# Uzes -> 20 hotels found
# Marseille -> 20 hotels found

# %%
hotels_clean_df = hotels_df.copy()

hotels_clean_df["review_score"] = (
    hotels_clean_df["review_score"]
    .astype(str)
    .str.replace(",", ".", regex=False)
    .str.extract(r"(\d+\.?\d*)")
    .astype(float)
)

hotels_clean_df = hotels_clean_df.fillna({
    "hotel_name": "Not Available",
    "review_score": 0,
    "booking_url": "Not Available"
})

hotels_clean_df
# Out:
#     city_id  city_name                                         hotel_name  \
# 0        16   Grenoble          Le Berthelot - Terrasse avec Vue Montagne
# 1        16   Grenoble     Apparthôtel Tempologis - St Germain à Grenoble
# 2        16   Grenoble  Appartement Loft centre ville situé dans rue c...
# 3        16   Grenoble            Villa atmosphère PETIT DEJEUNER COMPRIS
# 4        16   Grenoble                                         Good Vibes
# ..      ...        ...                                                ...
# 95       21  Marseille                           RockyPop Marseille Hôtel
# 96       21  Marseille                       Novotel Marseille Vieux Port
# 97       21  Marseille                                   HOTEL SYLVABELLE
# 98       21  Marseille  appartement renové , quartier historique du pa...
# 99       21  Marseille  Superbe Appartement, vue Notre Dame de la Gard...
#
#     review_score description  \
# 0            0.0        None
# 1            8.3        None
# 2            9.5        None
# 3            9.3        None
# 4            9.2        None
# ..           ...         ...
# 95           9.1        None
# 96           7.8        None
# 97           4.7        None
# 98           7.6        None
# 99           9.3        None
#
#                                           booking_url
# 0   https://www.booking.com/hotel/fr/le-berthelot-...
# 1   https://www.booking.com/hotel/fr/tempologis-gr...
# 2   https://www.booking.com/hotel/fr/appartement-l...
# 3   https://www.booking.com/hotel/fr/sarl-residila...
# 4   https://www.booking.com/hotel/fr/good-vibes-gr...
# ..                                                ...
# 95  https://www.booking.com/hotel/fr/citadines-apa...
# 96  https://www.booking.com/hotel/fr/novotel-marse...
# 97  https://www.booking.com/hotel/fr/sylvabelle-ma...
# 98  https://www.booking.com/hotel/fr/appart-renove...
# 99  https://www.booking.com/hotel/fr/superbe-appar...
#
# [100 rows x 6 columns]

# %% [markdown]
# ## 🔄 ETL - Data Transformation & Consolidation
#
# Once collected, weather and hotel datasets are merged
# to create an enriched travel dataset.
#
# Transformation steps include:
# - Cleaning of review score values
# - Standardization of numeric formats
# - Handling missing values
#
# The resulting dataset combines:
# - Geographical data
# - Weather indicators
# - Accommodation quality metrics
#
# This consolidated dataset represents a curated layer
# ready to be stored within the Data Lake.

# %% [markdown]
# ## Final Consolidation

# %%
enriched_travel_df = cities_weather_df.merge(
    hotels_clean_df,
    on=["city_id", "city_name"],
    how="left"
)

enriched_travel_df
# Out:
#      city_id          city_name    latitude   longitude  rain_7d  avg_temp_7d  \
# 0          1  Mont Saint Michel  48.6359541  -1.5114600     8.48    13.300000
# 1          2            St Malo  48.6495180  -2.0260409     7.58    13.542857
# 2          3             Bayeux  49.2764624  -0.7024738    13.50    13.542857
# 3          4           Le Havre  49.4938975   0.1079732    16.70    12.500000
# 4          5              Rouen  49.4404591   1.0939658    18.60    13.785714
# ..       ...                ...         ...         ...      ...          ...
# 125       31           Toulouse  43.6044638   1.4442433     2.40    16.528571
# 126       32          Montauban  44.0175835   1.3549991     2.40    16.442857
# 127       33           Biarritz  43.4832523  -1.5592776     0.60    16.657143
# 128       34            Bayonne  43.4945144  -1.4736657     0.60    17.085714
# 129       35        La Rochelle  46.1597320  -1.1515951    13.80    13.642857
#
#      weather_score hotel_name  review_score description booking_url
# 0         9.060000        NaN           NaN         NaN         NaN
# 1         9.752857        NaN           NaN         NaN         NaN
# 2         6.792857        NaN           NaN         NaN         NaN
# 3         4.150000        NaN           NaN         NaN         NaN
# 4         4.485714        NaN           NaN         NaN         NaN
# ..             ...        ...           ...         ...         ...
# 125      15.328571        NaN           NaN         NaN         NaN
# 126      15.242857        NaN           NaN         NaN         NaN
# 127      16.357143        NaN           NaN         NaN         NaN
# 128      16.785714        NaN           NaN         NaN         NaN
# 129       6.742857        NaN           NaN         NaN         NaN
#
# [130 rows x 11 columns]

# %%
enriched_travel_df.to_csv("enriched_travel_data.csv", index=False)

# %% [markdown]
# ## Data Lake Storage (AWS S3)
#
# The enriched dataset is uploaded to an AWS S3 bucket,
# which acts as a centralized Data Lake storage layer.
#
# This layer enables:
# - Persistent storage of collected external data
# - Decoupling between ingestion and analytics environments
# - Future scalability for additional travel-related datasets

# %% [markdown]
# ## Cloud Storage - AWS S3

# %%
import boto3
import os

# %%
S3_BUCKET_NAME = "kayak-data-lake-bucket"
S3_FILE_NAME = "enriched_travel_data.csv"
S3_OBJECT_PATH = "curated/enriched_travel_data.csv"

# %%
from dotenv import load_dotenv
load_dotenv()

AWS_ACCESS_KEY = os.getenv("AWS_ACCESS_KEY_ID")
AWS_SECRET_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")
AWS_REGION = os.getenv("AWS_DEFAULT_REGION")

# %%
s3_client = boto3.client(
    "s3",
    aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_KEY,
    region_name=AWS_REGION
)

# %%
s3_client.upload_file(
    Filename=S3_FILE_NAME,
    Bucket=S3_BUCKET_NAME,
    Key=S3_OBJECT_PATH,
)

# %% [markdown]
# ## Data Warehouse Loading (AWS RDS)
#
# To support downstream analytics and marketing decision-making,
# data stored in the Data Lake are extracted and loaded
# into a structured PostgreSQL database hosted on AWS RDS.
#
# This Data Warehouse provides:
# - Structured access to travel insights
# - Queryable datasets for business intelligence use cases
# - Reliable inputs for Kayak’s recommendation application

# %% [markdown]
# ## Data Warehouse - AWS RDS

# %%
from sqlalchemy import create_engine

# %% [markdown]
# ### Data Extraction from Data Lake

# %%
s3_client.download_file(
    Bucket=S3_BUCKET_NAME,
    Key=S3_OBJECT_PATH,
    Filename=S3_FILE_NAME
)

# %% [markdown]
# ### Data Transformation

# %%
extracted_travel_df  = pd.read_csv(S3_FILE_NAME)

# %% [markdown]
# ### RDS Configuration

# %%
RDS_HOST = os.getenv("RDS_HOST")
RDS_PORT = os.getenv("RDS_PORT")
RDS_DB = os.getenv("RDS_DB_NAME")
RDS_USER = os.getenv("RDS_USER")
RDS_PASSWORD = os.getenv("RDS_PASSWORD")

# %% [markdown]
# ### Database Connection

# %%
engine = create_engine(
    f"postgresql://{RDS_USER}:{RDS_PASSWORD}@{RDS_HOST}:{RDS_PORT}/{RDS_DB}"
)

# %% [markdown]
# ### Data Loading into Warehouse

# %%
extracted_travel_df.to_sql(
    name="travel_data",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 130

# %% [markdown]
# ### Data Verification

# %%
pd.read_sql("""
SELECT city_name, hotel_name, review_score
FROM travel_data
ORDER BY review_score DESC
LIMIT 10
""", engine)
# Out:
#                       city_name hotel_name review_score
# 0                       St Malo       None         None
# 1                        Bayeux       None         None
# 2                      Le Havre       None         None
# 3                         Rouen       None         None
# 4                         Paris       None         None
# 5                        Amiens       None         None
# 6                         Lille       None         None
# 7                    Strasbourg       None         None
# 8  Chateau du Haut Koenigsbourg       None         None
# 9             Mont Saint Michel       None         None

# %% [markdown]
# ## Decision-Support Dataset
#
# The structured dataset stored in the Data Warehouse
# can now be queried to:
#
# - Identify the most attractive destinations
# - Highlight top-rated hotels within those locations
#
# This enables Kayak’s Marketing team to:
# - Recommend destinations based on climate conditions
# - Suggest high-quality accommodation options

# %% [markdown]
# ## Top 20 Hotels Selection

# %%
top_20_hotels = extracted_travel_df.sort_values(
    by="review_score",
    ascending=False
).head(20)

top_20_hotels
# Out:
#      city_id  city_name   latitude  longitude  rain_7d  avg_temp_7d  \
# 66        23    Avignon  43.949249   4.805901      0.0    17.528571
# 60        23    Avignon  43.949249   4.805901      0.0    17.528571
# 78        23    Avignon  43.949249   4.805901      0.0    17.528571
# 82        24       Uzes  44.012128   4.419672      0.0    16.871429
# 97        24       Uzes  44.012128   4.419672      0.0    16.871429
# 116       25      Nimes  43.837425   4.360069      0.0    17.385714
# 85        24       Uzes  44.012128   4.419672      0.0    16.871429
# 74        23    Avignon  43.949249   4.805901      0.0    17.528571
# 92        24       Uzes  44.012128   4.419672      0.0    16.871429
# 112       25      Nimes  43.837425   4.360069      0.0    17.385714
# 95        24       Uzes  44.012128   4.419672      0.0    16.871429
# 114       25      Nimes  43.837425   4.360069      0.0    17.385714
# 17        16   Grenoble  45.187560   5.735782      0.0    17.671429
# 22        16   Grenoble  45.187560   5.735782      0.0    17.671429
# 89        24       Uzes  44.012128   4.419672      0.0    16.871429
# 88        24       Uzes  44.012128   4.419672      0.0    16.871429
# 23        16   Grenoble  45.187560   5.735782      0.0    17.671429
# 98        24       Uzes  44.012128   4.419672      0.0    16.871429
# 99        24       Uzes  44.012128   4.419672      0.0    16.871429
# 43        21  Marseille  43.296174   5.369953      0.0    16.842857
#
#      weather_score                                         hotel_name  \
# 66       17.528571  Maison climatisée intra-muros avec terrasse au...
# 60       17.528571  Grande maison de ville intra-muros - Calme & c...
# 78       17.528571  Le Complot : Maison privée en plein coeur d'Av...
# 82       16.871429                                 Le Pré Aux Cigales
# 97       16.871429  Secret d'Uzès - Le Duché - Piscine chauffée et...
# 116      17.385714  AfroBoHome, Expérience Atypique, clim, 2 à 6 p...
# 85       16.871429  La Grande Bourgade-Authentique Maison en Pierr...
# 74       17.528571                                           Chez Flo
# 92       16.871429                         La bohème place aux herbes
# 112      17.385714                  Roma Divine home cinéma et jardin
# 95       16.871429         Uzès Place aux Herbes Elégance Renaissance
# 114      17.385714         Chambres d'hôtes - Nîmes - Villa des roses
# 17       17.671429  Appartement Loft centre ville situé dans rue c...
# 22       17.671429     Le Bastille, 6 pers, 300 m gare, Climatisation
# 89       16.871429                       Beau T3 Vue Vallée De L'eure
# 88       16.871429      Villa piscine, spa & pétanque à Uzès centre !
# 23       17.671429  Le Téléphérique, 6 pers, 300 m Gare, Climatisa...
# 98       16.871429  Appartement cosy centre Uzès, parking gratuit,...
# 99       16.871429                               "La Suite" 3 Etoiles
# 43       16.842857             Loft 130m2 10pers idéal groupe famille
#
#      review_score  description  \
# 66           10.0          NaN
# 60           10.0          NaN
# 78            9.8          NaN
# 82            9.8          NaN
# 97            9.8          NaN
# 116           9.8          NaN
# 85            9.7          NaN
# 74            9.7          NaN
# 92            9.7          NaN
# 112           9.7          NaN
# 95            9.7          NaN
# 114           9.6          NaN
# 17            9.5          NaN
# 22            9.5          NaN
# 89            9.5          NaN
# 88            9.5          NaN
# 23            9.5          NaN
# 98            9.4          NaN
# 99            9.4          NaN
# 43            9.4          NaN
#
#                                            booking_url
# 66   https://www.booking.com/hotel/fr/maison-famili...
# 60   https://www.booking.com/hotel/fr/grande-maison...
# 78   https://www.booking.com/hotel/fr/le-complot-ma...
# 82   https://www.booking.com/hotel/fr/le-pre-aux-ci...
# 97   https://www.booking.com/hotel/fr/secret-d-uzes...
# 116  https://www.booking.com/hotel/fr/afrobohome-te...
# 85   https://www.booking.com/hotel/fr/la-grande-bou...
# 74   https://www.booking.com/hotel/fr/chez-flo-avig...
# 92   https://www.booking.com/hotel/fr/la-boheme-uze...
# 112  https://www.booking.com/hotel/fr/roma-divine-h...
# 95   https://www.booking.com/hotel/fr/uzes-place-au...
# 114  https://www.booking.com/hotel/fr/chambre-d-hot...
# 17   https://www.booking.com/hotel/fr/appartement-l...
# 22   https://www.booking.com/hotel/fr/le-bastille-6...
# 89   https://www.booking.com/hotel/fr/vallee-de-l-e...
# 88   https://www.booking.com/hotel/fr/villa-piscine...
# 23   https://www.booking.com/hotel/fr/le-telepheriq...
# 98   https://www.booking.com/hotel/fr/appartement-c...
# 99   https://www.booking.com/hotel/fr/la-suite-a-50...
# 43   https://www.booking.com/hotel/fr/t4-loft-parad...

# %%
import plotly.express as px

# %%
fig = px.scatter_map(
    top_20_hotels,
    lat="latitude",
    lon="longitude",
    size="review_score",
    color="review_score",
    hover_name="hotel_name",
    hover_data=["city_name"],
    zoom=5,
    height=600
)

fig.show()
